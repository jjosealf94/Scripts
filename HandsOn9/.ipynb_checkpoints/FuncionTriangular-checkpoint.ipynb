# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def Bm(h,L,d,m):
        return (2.*h*(L**2)/((m**2)*(pi**2)*d*(L-d)))*sin(m*pi*d/L)

def SerieF(h,L,d,m,x):
    return Bm(h,L,d,m)*sin(m*pi*x/L)
 

xlin=linspace(0,3,100)
figure(figsize(15,5))
yaux=0
title("Serie de Fourier de una Función triangular")
for i in range(1,21,1):
    yaux+=SerieF(1,3,1,i,xlin)
    if i%3==0:
        plot(xlin,yaux,label=str(i))
legend()
show()
